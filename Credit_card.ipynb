# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('UCI_Credit_Card.csv')

# %%
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# ...

# %%
#EDA

# %%
df.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
df.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default.payment.next.month    0
# dtype: int64

# %%
df.rename(columns = {'default.payment.next.month':'def_pay'},inplace=True)

# %%
df.rename(columns = {'PAY_0':'PAY_1'},inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         30000 non-null  int64
#  1   LIMIT_BAL  30000 non-null  float64
#  2   SEX        30000 non-null  int64
#  3   EDUCATION  30000 non-null  int64
#  4   MARRIAGE   30000 non-null  int64
#  5   AGE        30000 non-null  int64
#  6   PAY_1      30000 non-null  int64
#  7   PAY_2      30000 non-null  int64
#  8   PAY_3      30000 non-null  int64
#  9   PAY_4      30000 non-null  int64
#  10  PAY_5      30000 non-null  int64
#  11  PAY_6      30000 non-null  int64
#  12  BILL_AMT1  30000 non-null  float64
#  13  BILL_AMT2  30000 non-null  float64
#  14  BILL_AMT3  30000 non-null  float64
#  15  BILL_AMT4  30000 non-null  float64
#  16  BILL_AMT5  30000 non-null  float64
#  17  BILL_AMT6  30000 non-null  float64
#  18  PAY_AMT1   30000 non-null  float64
# ...

# %%
df['def_pay'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
counts = df['def_pay'].value_counts()

# %%
plt.figure(figsize = (6,6))
plt.pie(counts,labels = counts.index,autopct='%1.1f%%',startangle=140)
plt.title('pieplot of 0 and 1s')
plt.show()

# %%
sns.distplot(df['LIMIT_BAL'])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_16264\1953226793.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['LIMIT_BAL'])
# <Axes: xlabel='LIMIT_BAL', ylabel='Density'>

# %%
for column in df[['AGE','LIMIT_BAL']]:
    sns.displot(df[column],kde=True,bins=20)
    plt.title(f'distribution of {column}')
    plt.show()
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  def_pay
# 0       0.0       0.0       0.0        1
# ...

# %%
pd.set_option('display.max_columns',None)

# %%
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
#
#    PAY_5  PAY_6  BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  BILL_AMT5  \
# 0     -2     -2     3913.0     3102.0      689.0        0.0        0.0
# 1      0      2     2682.0     1725.0     2682.0     3272.0     3455.0
# 2      0      0    29239.0    14027.0    13559.0    14331.0    14948.0
# 3      0      0    46990.0    48233.0    49291.0    28314.0    28959.0
# 4      0      0     8617.0     5670.0    35835.0    20940.0    19146.0
#
#    BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# ...

# %%
g = sns.FacetGrid(df, row='def_pay', col='MARRIAGE')
g = g.map(plt.hist, 'AGE')
plt.show()
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df['MARRIAGE'].unique()
# Out:
# array([1, 2, 3, 0], dtype=int64)

# %%
    df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
#
#    PAY_5  PAY_6  BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  BILL_AMT5  \
# 0     -2     -2     3913.0     3102.0      689.0        0.0        0.0
# 1      0      2     2682.0     1725.0     2682.0     3272.0     3455.0
# 2      0      0    29239.0    14027.0    13559.0    14331.0    14948.0
# 3      0      0    46990.0    48233.0    49291.0    28314.0    28959.0
# 4      0      0     8617.0     5670.0    35835.0    20940.0    19146.0
#
#    BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# ...

# %%
df['EDUCATION'].unique()
# Out:
# array([2, 1, 3, 5, 4, 6, 0], dtype=int64)

# %%
df['PAY_1'].unique()
# Out:
# array([ 2, -1,  0, -2,  1,  3,  4,  8,  7,  5,  6], dtype=int64)

# %%
fig,axes = plt.subplots(3,3,figsize=(15,10))
axes = axes.flatten()

cat_cols = ['SEX','EDUCATION','MARRIAGE','PAY_1','PAY_2','PAY_3','PAY_4','PAY_5','PAY_6']

for i,column in enumerate(df[cat_cols]):
    sns.countplot(x = column,data=df,ax = axes[i],palette = 'viridis')
    axes[i].set_title(f'Bar plot for {column}')
    axes[i].set_xlabel(column)
    axes[i].set_ylabel('Count')
    
plt.tight_layout()
plt.show()

# %%
from scipy.stats import chi2_contingency

# %%
df_cat = df[cat_cols].columns.tolist()

# %%
df_cat
# Out:
# ['SEX',
#  'EDUCATION',
#  'MARRIAGE',
#  'PAY_1',
#  'PAY_2',
#  'PAY_3',
#  'PAY_4',
#  'PAY_5',
#  'PAY_6']

# %%
chi2_results = {}

for i ,feature1 in enumerate(cat_cols):
    for feature2 in cat_cols[i+1:]:
        contingency_table = pd.crosstab(df[feature1],df[feature2])
        chi2,p,dof,expected = chi2_contingency(contingency_table)
        
        chi2_results[(feature1,feature2)] = {
            'Chi-Square':chi2,
            'P-value':p,
            'Degrees of freedom':dof,
            'Expected Frequencies':expected
        }
        
chi2_results
# Out:
# {('SEX', 'EDUCATION'): {'Chi-Square': 30.801920377570426,
#   'P-value': 2.765464336611277e-05,
#   'Degrees of freedom': 6,
#   'Expected Frequencies': array([[5.54773333e+00, 4.19448267e+03, 5.55962133e+03, 1.94844320e+03,
#           4.87408000e+01, 1.10954667e+02, 2.02096000e+01],
#          [8.45226667e+00, 6.39051733e+03, 8.47037867e+03, 2.96855680e+03,
#           7.42592000e+01, 1.69045333e+02, 3.07904000e+01]])},
#  ('SEX', 'MARRIAGE'): {'Chi-Square': 33.01008280625234,
#   'P-value': 3.2049390980663363e-07,
#   'Degrees of freedom': 3,
#   'Expected Frequencies': array([[  21.3984    , 5412.6064    , 6326.00106667,  127.99413333],
#          [  32.6016    , 8246.3936    , 9637.99893333,  195.00586667]])},
#  ('SEX', 'PAY_1'): {'Chi-Square': 139.5902742041607,
#   'P-value': 5.113156610286346e-25,
#   'Degrees of freedom': 10,
#   'Expected Frequencies': array([[1.09329973e+03, 2.25317227e+03, 5.83978187e+03, 1.46143147e+03,
# ...

# %%
plt.subplots(figsize=(30,20))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
df.drop(columns=['ID'],inplace=True)

# %%
from sklearn.model_selection import train_test_split

# %%
df.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0    20000.0    2          2         1   24      2      2     -1     -1
# 1   120000.0    2          2         2   26     -1      2      0      0
# 2    90000.0    2          2         2   34      0      0      0      0
# 3    50000.0    2          2         1   37      0      0      0      0
# 4    50000.0    1          2         1   57     -1      0     -1      0
#
#    PAY_5  PAY_6  BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  BILL_AMT5  \
# 0     -2     -2     3913.0     3102.0      689.0        0.0        0.0
# 1      0      2     2682.0     1725.0     2682.0     3272.0     3455.0
# 2      0      0    29239.0    14027.0    13559.0    14331.0    14948.0
# 3      0      0    46990.0    48233.0    49291.0    28314.0    28959.0
# 4      0      0     8617.0     5670.0    35835.0    20940.0    19146.0
#
#    BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# ...

# %%
num_features = ['LIMIT_BAL','BILL_AMT1','BILL_AMT2','BILL_AMT3','BILL_AMT4','BILL_AMT5','BILL_AMT6','PAY_AMT1','PAY_AMT2','PAY_AMT3','PAY_AMT4','PAY_AMT5','PAY_AMT6']

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
df[num_features] = scaler.fit_transform(df[num_features])

# %%
df.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0   0.010101    2          2         1   24      2      2     -1     -1
# 1   0.111111    2          2         2   26     -1      2      0      0
# 2   0.080808    2          2         2   34      0      0      0      0
# 3   0.040404    2          2         1   37      0      0      0      0
# 4   0.040404    1          2         1   57     -1      0     -1      0
#
#    PAY_5  PAY_6  BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  BILL_AMT5  \
# 0     -2     -2   0.149982   0.069164   0.086723   0.160138   0.080648
# 1      0      2   0.148892   0.067858   0.087817   0.163220   0.084074
# 2      0      0   0.172392   0.079532   0.093789   0.173637   0.095470
# 3      0      0   0.188100   0.111995   0.113407   0.186809   0.109363
# 4      0      0   0.154144   0.071601   0.106020   0.179863   0.099633
#
#    BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# ...

# %%
X = df.drop(['def_pay'], axis=1)
Y = df.def_pay

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=10)

# %%
from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
param_grid = [    
    {'penalty' : ['l1', 'l2', 'elasticnet', 'none'],
    'C' : np.logspace(-4, 4, 20),
    'solver' : ['lbfgs','newton-cg','liblinear','sag','saga'],
    'max_iter' : [100, 1000,2500, 5000]
    }
]

# %%
from sklearn.model_selection import GridSearchCV

# %%
logModel_l2 = LogisticRegression(penalty='l2',C=2,solver='lbfgs')

# %%
#clf = GridSearchCV(logModel, param_grid = param_grid, cv = 3, verbose=True, n_jobs=-1)

# %%
logModel_l2.fit(X_train,y_train)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(C=2)

# %%
y_pred = logModel_l2.predict(X_test)

# %%
cm = confusion_matrix(y_test,y_pred)

# %%
cm
# Out:
# array([[4571,  112],
#        [1009,  308]], dtype=int64)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8131666666666667

# %%
cr = classification_report(y_test,y_pred)

# %%
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.98      0.89      4683
#            1       0.73      0.23      0.35      1317
#
#     accuracy                           0.81      6000
#    macro avg       0.78      0.60      0.62      6000
# weighted avg       0.80      0.81      0.77      6000

# %%
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(criterion = 'entropy',splitter='best')
cv = cross_val_score(clf, X_train, y_train, cv=10)

# %%
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
y_pred = clf.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7263333333333334

# %%
cr = classification_report(y_test,y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.81      0.82      4683
#            1       0.39      0.42      0.41      1317
#
#     accuracy                           0.73      6000
#    macro avg       0.61      0.62      0.61      6000
# weighted avg       0.74      0.73      0.73      6000

# %%
from sklearn.svm import SVC

# %%
SV = SVC(gamma='auto')

# %%
SV.fit(X_train,y_train)
# Out:
# SVC(gamma='auto')

# %%
y_pred = SV.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8233333333333334

# %%
cr = classification_report(y_test,y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.96      0.89      4683
#            1       0.70      0.34      0.46      1317
#
#     accuracy                           0.82      6000
#    macro avg       0.77      0.65      0.68      6000
# weighted avg       0.81      0.82      0.80      6000

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(n_estimators=250,random_state=45).fit(X_train, y_train)

# %%
rf_y_pred = rf_model.predict(X_test)

# %%
# Accuracy, Precision and Recall
from sklearn.metrics import accuracy_score, precision_score, recall_score
score1 = accuracy_score(y_test, rf_y_pred)
score2 = precision_score(y_test, rf_y_pred)
score3 = recall_score(y_test, rf_y_pred)
print("---- Scores ----")
print("Accuracy score is: {}%".format(round(score1*100,2)))
print("Precision score is: {}".format(round(score2,2)))
print("Recall score is: {}".format(round(score3,2)))
# Out:
# ---- Scores ----
# Accuracy score is: 82.03%
# Precision score is: 0.66
# Recall score is: 0.37

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
rf_cm = confusion_matrix(y_test, rf_y_pred)

# %%
# Plotting the confusion matrix
plt.figure(figsize=(10,7))
sns.heatmap(data=rf_cm, annot=True, cmap="Blues", xticklabels=['Real', 'Fake'], yticklabels=['Real', 'Fake'])
plt.xlabel('Predicted values')
plt.ylabel('Actual values')
plt.title('Confusion Matrix for Random Forest Algorithm')
plt.show()

# %%
# Hyperparameter tuning the Logistic Regression Classifier
best_accuracy = 0.0
c_val = 0.0
for i in [100,125,150,175,200,225,250,275,300]:
  temp_classifier = RandomForestClassifier(n_estimators=i,random_state=45).fit(X_train, y_train)
  temp_classifier.fit(X_train, y_train)
  temp_y_pred = temp_classifier.predict(X_test)
  score = accuracy_score(y_test, temp_y_pred)
  print("Accuracy score for C={} is: {}%".format(round(i,1), round(score*100,2)))
  if score>best_accuracy:
    best_accuracy = score
    c_val = i
print('--------------------------------------------')
print('The best accuracy is {}% with C value as {}'.format(round(best_accuracy*100, 2), round(c_val,1)))
# Out:
# Accuracy score for C=100 is: 82.03%
# Accuracy score for C=125 is: 81.97%
# Accuracy score for C=150 is: 81.98%
# Accuracy score for C=175 is: 81.9%
# Accuracy score for C=200 is: 81.87%
# Accuracy score for C=225 is: 82.03%
# Accuracy score for C=250 is: 82.03%
# Accuracy score for C=275 is: 81.98%
# Accuracy score for C=300 is: 81.97%
# --------------------------------------------
# The best accuracy is 82.03% with C value as 100

# %%
cr = classification_report(y_test,rf_y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.95      0.89      4683
#            1       0.66      0.37      0.48      1317
#
#     accuracy                           0.82      6000
#    macro avg       0.75      0.66      0.68      6000
# weighted avg       0.80      0.82      0.80      6000

# %%
import tensorflow as tf

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from keras import Sequential
from keras.callbacks import EarlyStopping
from keras.callbacks import LearningRateScheduler
from keras.layers import Dense, Dropout
from keras.layers import BatchNormalization

# %%
from tensorflow.keras import layers

# %%
tf.random.set_seed(42)
model = Sequential()
model.add(Dense(512, activation='relu'))
model.add(layers.BatchNormalization())
model.add(Dropout(0.7))
model.add(Dense(256, activation='relu'))
model.add(layers.BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
model.add(layers.BatchNormalization())
model.add(Dropout(0.4))
model.add(Dense(64, activation='relu'))
model.add(layers.BatchNormalization())
model.add(Dropout(0.3))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
lr_scheduler = LearningRateScheduler(lambda epoch: 1e-4 * 10 ** (epoch / 10))

# %%
model.compile(loss='binary_crossentropy', optimizer=tf.keras.optimizers.Adam(learning_rate=0.00085), metrics=['AUC'])
history = model.fit(X_train, y_train, epochs=50, callbacks=[early_stopping, lr_scheduler],
                    validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 21s 10ms/step - AUC: 0.5504 - loss: 0.7440 - val_AUC: 0.7181 - val_loss: 0.4710 - learning_rate: 1.0000e-04
# Epoch 2/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - AUC: 0.6290 - loss: 0.5367 - val_AUC: 0.7424 - val_loss: 0.4647 - learning_rate: 1.2589e-04
# Epoch 3/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - AUC: 0.6658 - loss: 0.5067 - val_AUC: 0.7532 - val_loss: 0.4552 - learning_rate: 1.5849e-04
# Epoch 4/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - AUC: 0.6917 - loss: 0.4907 - val_AUC: 0.7600 - val_loss: 0.4486 - learning_rate: 1.9953e-04
# Epoch 5/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - AUC: 0.7044 - loss: 0.4822 - val_AUC: 0.7655 - val_loss: 0.4434 - learning_rate: 2.5119e-04
# Epoch 6/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - AUC: 0.7200 - loss: 0.4719 - val_AUC: 0.7698 - val_loss: 0.4411 - learning_rate: 3.1623e-04
# Epoch 7/50
# ...

# %%
y_pred = model.predict(X_test)
# Out:
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step

# %%
rf_cm = confusion_matrix(y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 rf_cm = confusion_matrix(y_test, y_pred)
#
# File ~\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:317, in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     232 def confusion_matrix(
#     233     y_true, y_pred, *, labels=None, sample_weight=None, normalize=None
#     234 ):
#     235     """Compute confusion matrix to evaluate the accuracy of a classification.
#     236
#     237     By definition a confusion matrix :math:`C` is such that :math:`C_{i, j}`
#    (...)
#     315     (0, 2, 1, 1)
#     316     """
# --> 317     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     318     if y_type not in ("binary", "multiclass"):
#     319         raise ValueError("%s is not supported" % y_type)
#
# ...

# %%
df.head()

# %%
#!pip install scikit-learn==1.2.2 --user

# %%
#!pip install imblearn

# %%
from imblearn.over_sampling import SMOTE

# %%
# Resampling the minority class. The strategy can be changed as required.
sm = SMOTE(sampling_strategy='minority', random_state=42)
# Fit the model to generate the data.
oversampled_X, oversampled_Y = sm.fit_resample(df.drop('def_pay', axis=1), df['def_pay'])
df_new = pd.concat([pd.DataFrame(oversampled_Y), pd.DataFrame(oversampled_X)], axis=1)

# %%
X = df_new.drop(['def_pay'], axis=1)
Y = df_new.def_pay

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=10)

# %%
df_new.shape
# Out:
# (46728, 24)

# %%
logModel_l2 = LogisticRegression(penalty='l2',C=2,solver='lbfgs')

# %%
logModel_l2.fit(X_train,y_train)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(C=2)

# %%
y_pred = logModel_l2.predict(X_test)

# %%
cr = classification_report(y_test,y_pred)

# %%
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.71      0.69      4665
#            1       0.69      0.66      0.68      4681
#
#     accuracy                           0.69      9346
#    macro avg       0.69      0.69      0.69      9346
# weighted avg       0.69      0.69      0.69      9346

# %%
rf_model = RandomForestClassifier(n_estimators=250,random_state=45).fit(X_train, y_train)

# %%
rf_y_pred = rf_model.predict(X_test)

# %%
# Plotting the confusion matrix
plt.figure(figsize=(10,7))
sns.heatmap(data=rf_cm, annot=True, cmap="Blues", xticklabels=['Real', 'Fake'], yticklabels=['Real', 'Fake'])
plt.xlabel('Predicted values')
plt.ylabel('Actual values')
plt.title('Confusion Matrix for Random Forest Algorithm')
plt.show()

# %%
# Hyperparameter tuning the Logistic Regression Classifier
best_accuracy = 0.0
c_val = 0.0
for i in [100,125,150,175,200,225,250,275,300]:
  temp_classifier = RandomForestClassifier(n_estimators=i,random_state=45).fit(X_train, y_train)
  temp_classifier.fit(X_train, y_train)
  temp_y_pred = temp_classifier.predict(X_test)
  score = accuracy_score(y_test, temp_y_pred)
  print("Accuracy score for C={} is: {}%".format(round(i,1), round(score*100,2)))
  if score>best_accuracy:
    best_accuracy = score
    c_val = i
print('--------------------------------------------')
print('The best accuracy is {}% with C value as {}'.format(round(best_accuracy*100, 2), round(c_val,1)))
# Out:
# Accuracy score for C=100 is: 83.02%
# Accuracy score for C=125 is: 83.33%
# Accuracy score for C=150 is: 83.06%
# Accuracy score for C=175 is: 83.24%
# Accuracy score for C=200 is: 83.06%
# Accuracy score for C=225 is: 83.17%
# Accuracy score for C=250 is: 83.12%
# Accuracy score for C=275 is: 83.14%
# Accuracy score for C=300 is: 83.18%
# --------------------------------------------
# The best accuracy is 83.33% with C value as 125

# %%
cr = classification_report(y_test,rf_y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.86      0.84      4665
#            1       0.85      0.80      0.83      4681
#
#     accuracy                           0.83      9346
#    macro avg       0.83      0.83      0.83      9346
# weighted avg       0.83      0.83      0.83      9346

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train_nn = sc.fit_transform(X_train)
x_test_nn = sc.transform(X_test)
tf.random.set_seed(42)
model = Sequential()
model.add(Dense(512, activation='relu'))
model.add(layers.BatchNormalization())
model.add(Dropout(0.7))
model.add(Dense(256, activation='relu'))
model.add(layers.BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
model.add(layers.BatchNormalization())
model.add(Dropout(0.4))
model.add(Dense(64, activation='relu'))
model.add(layers.BatchNormalization())
model.add(Dropout(0.3))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
lr_scheduler = LearningRateScheduler(lambda epoch: 1e-4 * 10 ** (epoch / 10))

# %%
x_train_nn.shape
# Out:
# (37382, 23)

# %%
y_train.shape
# Out:
# (37382,)

# %%
model.compile(loss='binary_crossentropy', optimizer=tf.keras.optimizers.Adam(learning_rate=0.00085), metrics=['AUC'])
history = model.fit(x_train_nn, y_train, epochs=50, callbacks=[early_stopping, lr_scheduler],
                    validation_data=(x_test_nn, y_test))
# Out:
# Epoch 1/50
# 1169/1169 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - AUC: 0.6835 - loss: 0.6487 - val_AUC: 0.7636 - val_loss: 0.5798 - learning_rate: 1.0000e-04
# Epoch 2/50
# 1169/1169 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - AUC: 0.7083 - loss: 0.6266 - val_AUC: 0.7657 - val_loss: 0.5764 - learning_rate: 1.2589e-04
# Epoch 3/50
# 1169/1169 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - AUC: 0.7296 - loss: 0.6058 - val_AUC: 0.7669 - val_loss: 0.5722 - learning_rate: 1.5849e-04
# Epoch 4/50
# 1169/1169 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - AUC: 0.7392 - loss: 0.5974 - val_AUC: 0.7678 - val_loss: 0.5698 - learning_rate: 1.9953e-04
# Epoch 5/50
# 1169/1169 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - AUC: 0.7494 - loss: 0.5884 - val_AUC: 0.7736 - val_loss: 0.5651 - learning_rate: 2.5119e-04
# Epoch 6/50
# 1169/1169 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - AUC: 0.7534 - loss: 0.5841 - val_AUC: 0.7759 - val_loss: 0.5632 - learning_rate: 3.1623e-04
# Epoch 7/50
# ...

# %%
rf_model.feature_importances_
# Out:
# array([0.0842075 , 0.01206302, 0.02013761, 0.01303843, 0.0592432 ,
#        0.08881198, 0.04483559, 0.02963381, 0.02405321, 0.01943828,
#        0.01667308, 0.05431304, 0.04901981, 0.04739633, 0.04543001,
#        0.04617023, 0.04583163, 0.05262328, 0.05321088, 0.04836071,
#        0.04621465, 0.04696951, 0.0523242 ])

# %%
plt.barh(X.columns, rf_model.feature_importances_)
# Out:
# <BarContainer object of 23 artists>
